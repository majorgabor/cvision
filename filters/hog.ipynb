# %%
import matplotlib.pyplot as plt
from skimage.feature import hog
from skimage import data, exposure

# %%
img = plt.imread("./einstein.jpg")
_, hog = hog(img, orientations=8, pixels_per_cell=(16,16), cells_per_block=(1,1), visualize=True)
hog = exposure.rescale_intensity(hog, in_range=(0,10))
# Out:
# /home/gabor/.local/lib/python3.10/site-packages/skimage/_shared/compat.py:6: UserWarning: A NumPy version >=1.23.5 and <2.3.0 is required for this version of SciPy (detected version 1.21.5)
#   import scipy as sp

# %%
plt.figure(figsize=(20,10))
plt.subplot(1,2,1)
plt.imshow(img, cmap="gray")
plt.subplot(1,2,2)
plt.imshow(hog, cmap="gray")
